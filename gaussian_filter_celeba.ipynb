# %% [markdown]
# <a href="https://colab.research.google.com/github/manushiez/gaussian-filter-celeba/blob/main/gaussian_filter_celeba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d6f798c6-4de0-4f00-a3b2-7dc352988539" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6f798c6-4de0-4f00-a3b2-7dc352988539">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d jessicali9530/celeba-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jessicali9530/celeba-dataset
# License(s): other
# celeba-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('celeba-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import os
import cv2
import matplotlib.pyplot as plt
from glob import glob

images_path = '/content/img_align_celeba/img_align_celeba/'

image_files = sorted(glob(images_path + '*.jpg'))[:10]

def apply_gaussian_filter(image):
    return cv2.GaussianBlur(image, (15, 15), 0)

plt.figure(figsize=(20, 10))

for i, image_file in enumerate(image_files):
    image = cv2.imread(image_file)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    filtered_image = apply_gaussian_filter(image)

    plt.subplot(2, 10, i + 1)
    plt.imshow(image)
    plt.axis('off')
    plt.title('Original')

    plt.subplot(2, 10, i + 11)
    plt.imshow(filtered_image)
    plt.axis('off')
    plt.title('Gaussian Filtered')

plt.tight_layout()
plt.show()
